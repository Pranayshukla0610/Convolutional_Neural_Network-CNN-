# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/Convolutional_Neural_Network-CNN-/blob/main/MLOPS_CNN_On_Cifar_Datat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

folders = [
    'cnn_project',
    'cnn_project/data',
    'cnn_project/src',
    'cnn_project/src/components',
    'cnn_project/src/pipeline',
    'cnn_project/src/utils',
    'cnn_project/models',
    'cnn_project/logs',
    'cnn_project/artifacts',
    'cnn_project/config'
]

for folder in folders:
  os.makedirs(folder, exist_ok = True)

print("Full project created successfully!")
# Out:
# Full project created successfully!

# %%
# !pip install tensorflow matplotlib seaborn pyyaml

# %%
config_yaml = """
data:
  batch_size: 64
  img_size: 32

training:
  epochs: 10
  learning_rate: 0.001

model:
  num_classes: 10

paths:
  model_path: cnn_project/models/cnn_model.h5
  log_path: cnn_project/logs/log.txt
"""

with open('cnn_project/config/config.yaml','w') as f:
  f.write(config_yaml)

print("Config file created!")
# Out:
# Config file created!

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10

def load_data():
  (X_train, y_train), (X_test, y_test) = cifar10.load_data()
  return X_train, X_test, y_train, y_test

# %%
import matplotlib.pyplot as plt
def plot_sample_images():
  class_names = ['airplane','auto','bird','cat','deer','dog','frog','horse','ship','truck']

  plt.figure(figsize=(10,6))
  for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(X[i])
    plt.title(class_names[int(y[i])])
    plt.axis('off')
  plt.show()

# %%
import tensorflow as tf

def preprocess(X_train, X_test):
  X_train = X_train/255.0
  X_test = X_test/255.0
  return X_train, X_test

# %%
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

def build_model(num_classes=10):
  model = models.Sequential()

  model.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,3,3)))
  model.add(layers.MaxPooling2D((2,2)))

  model.add(layers.Conv2D(64,(3,3), activation='relu'))
  model.add(layers.MaxPooling2D((2,2)))

  model.add(layers.Conv2D(128,(3,3), activation='relu'))

  model.add(layers.flatten())
  model.add(layers, Dense(128, activation='relu'))
  model.add(num_classes, activation='softmax')

  return model

# %%
import tensorflow as tf

def train_model(model, X_train, y_train, epochs, batch_size):
    model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_split=0.2
    )

    return history

# %%
def evaluate_model(model, X_test, y_test):
    loss, accuracy = model.evaluate(X_test, y_test)
    print(f"Test Accuracy: {accuracy}")
